# %% [markdown]
# # LangGraph
#
# - [Install LangGraph](https://docs.langchain.com/oss/python/langgraph/install)
# - [Quickstart](https://docs.langchain.com/oss/python/langgraph/quickstart)
#   - [MCP](https://docs.langchain.com/use-these-docs#connect-with-vs-code)
#   - [Skills](https://github.com/langchain-ai/langchain-skills)
#
# # Microsoft Foundry
#
# - [Use LangChain with models in Microsoft Foundry](https://learn.microsoft.com/en-us/azure/foundry/how-to/develop/langchain-models)
# - [LangChain Docs / Microsoft integrations](https://docs.langchain.com/oss/python/integrations/providers/microsoft#azure-ai)

# %%
# !uv run python ../../scripts/microsoft_foundry/vanilla.py --help
# Out:
#
#  Usage: vanilla.py [OPTIONS] COMMAND [ARGS]...
#
#  Microsoft Foundry CLI
#
# ╭─ Options ────────────────────────────────────────────────────────────────────╮
# │ --tracing          [on|off]  Enable Azure AI Foundry / Azure Monitor tracing │
# │                              for LangChain runs. See                         │
# │                              https://learn.microsoft.com/en-us/azure/foundr… │
# │                              [default: off]                                  │
# │ --verbose  -v                Enable verbose (DEBUG) logging                  │
# │ --help                       Show this message and exit.                     │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Commands ───────────────────────────────────────────────────────────────────╮
# │ hello-world          Use chat models:                                        │
# │                      https://learn.microsoft.com/en-us/azure/foundry/how-to… │
# │ configurable         Configurable models:                                    │
# │                      https://learn.microsoft.com/en-us/azure/foundry/how-to… │
# │ direct-client        Configure clients directly:                             │
# │                      https://learn.microsoft.com/en-us/azure/foundry/how-to… │
# │ async-call           Run asynchronous calls:                                 │
# │                      https://learn.microsoft.com/en-us/azure/foundry/how-to… │
# │ reasoning            Reasoning:                                              │
# │                      https://learn.microsoft.com/en-us/azure/foundry/how-to… │
# │ server-side-tools    Server-side tools:                                      │
# │                      https://learn.microsoft.com/en-us/azure/foundry/how-to… │
# │ use-in-agents        Use Foundry models in agents:                           │
# │                      https://learn.microsoft.com/en-us/azure/foundry/how-to… │
# │ embeddings           Use embedding models:                                   │
# │                      https://learn.microsoft.com/en-us/azure/foundry/how-to… │
# │ embeddings-direct    Use embedding models (direct client):                   │
# │                      https://learn.microsoft.com/en-us/azure/foundry/how-to… │
# │ vector-store-search  Example: Run similarity search with a vector store:     │
# │                      https://learn.microsoft.com/en-us/azure/foundry/how-to… │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
# !uv run python ../../scripts/microsoft_foundry/vanilla.py hello-world
# Out:
# ================================== Ai Message ==================================
#
# [{'id': 'rs_0922953ae11a9fd60069ffe9b18abc81949a61e7f3d53d08df', 'summary': [], 'type': 'reasoning', 'response_id': 'resp_0922953ae11a9fd60069ffe9b030f88194ba5dfe1b920f9e5a'}, {'type': 'text', 'text': 'I’m doing well, thanks for asking! How are you? What can I help you with today?', 'annotations': [], 'id': 'msg_0922953ae11a9fd60069ffe9b29fb4819496cc8530b7b0fb7d'}]

# %%
# !uv run python ../../scripts/microsoft_foundry/vanilla.py embeddings
# Out:
# Embedding length: 1536
# First 8 dims: [-0.0184326171875, -0.007236480712890625, 0.003627777099609375, -0.054229736328125, -0.0226898193359375, 0.0369873046875, 0.0290374755859375, 0.023895263671875]

# %%
# !uv run python ../../scripts/microsoft_foundry/vanilla.py vector-store-search --query foo
# Out:
# * foo [{'baz': 'bar'}]

# %% [markdown]
# # Tracing
#
# - [Trace LangChain and LangGraph apps with Microsoft Foundry and Azure Monitor](https://learn.microsoft.com/en-us/azure/foundry/how-to/develop/langchain-traces)
# - [Monitor your generative AI applications (preview) (classic)](https://learn.microsoft.com/en-us/azure/foundry-classic/how-to/monitor-applications)

# %%
# !uv run python ../../scripts/microsoft_foundry/vanilla.py --tracing on \
    hello-world --query "千葉ジェッツについておしえて"
# Out:
# ================================== Ai Message ==================================
#
# [{'id': 'rs_0ebd994e023423a40069ffe9c018c881908a014d4ef22027fb', 'summary': [], 'type': 'reasoning', 'response_id': 'resp_0ebd994e023423a40069ffe9bf4a7c819099682bf602bcb122'}, {'type': 'text', 'text': '千葉ジェッツ（正式名：千葉ジェッツふなばし）は、千葉県船橋市をホームタウンとするB.LEAGUE（B1・東地区）のプロバスケットボールクラブです。概要を手短にまとめます。\n\n- 概要\n  - 設立・参入：2011年にbjリーグへ参入、2016年のB.LEAGUE発足時からB1所属\n  - ホームタウン：千葉県船橋市\n  - チームカラー：レッドを基調とした「JETS RED」\n  - ホームアリーナ：船橋アリーナ（他に千葉ポートアリーナ等での開催実績もあり）\n  - ファン呼称：ブースター\n\n- 主な実績\n  - B.LEAGUE優勝：1回（2020–21シーズン）\n  - 天皇杯（全日本バスケットボール選手権）：複数回優勝（特に2017–2019の3連覇で知られる）\n  - 2022–23シーズン：レギュラーシーズン53勝7敗（当時リーグ最多勝記録）でファイナル進出\n\n- チームの特徴\n  - 日本屈指の人気・動員を誇る強豪クラブ\n  - ハイスピードなトランジション、3Pとディフェンス強度のバランスが取れたスタイル\n  - 司令塔・富樫勇樹（日本代表経験、BリーグMVP経験）を中心に、国内主力と助っ人の融合で毎季上位を争う\n\n- 観戦情報\n  - 試合：B1東地区でレギュラーシーズン60試合前後（ホーム/アウェー）\n  - 配信：バスケットLIVE（B.LEAGUE公式配信サービス）などで視聴可能\n  - チケット：B.LEAGUEチケットや公式サイトから販売\n\n- ライバル/見どころ\n  - 東地区の強豪（アルバルク東京、宇都宮ブレックス）や、ファイナルで当たることの多い琉球ゴールデンキングスなどとの上位対決は必見\n  - 演出やブースターの一体感が強く、会場の盛り上がりが大きな魅力\n\n必要なら、今季のロスターや試合日程、チケットの取り方、注目選手の詳しい紹介もお手伝いします。どのあたりを詳しく知りたいですか？', 'annotations': [], 'id': 'msg_0ebd994e023423a40069ffe9ddc214819095f83562ee772cf2'}]
